# %%
current_year = 2021
type(current_year)
# Out:
# int

# %%
7+5
# Out:
# 12

# %%
7*5
# Out:
# 35

# %%
10**4
# Out:
# 10000

# %%
35/7
# Out:
# 5.0

# %%
35//7
# Out:
# 5

# %%
35%7
# Out:
# 0

# %%
36%7
# Out:
# 1

# %%
print (" vipul trivedi here, Glad to learn from you ")
# Out:
#  vipul trivedi here, Glad to learn from you

# %%
type (print)
# Out:
# builtin_function_or_method

# %%
one_hundredth = 2e-2
one_hundredth
# Out:
# 0.02

# %%
type(one_hundredth)
# Out:
# float

# %%
"Hello"
# Out:
# 'Hello'

# %%
a= 32
b= 20
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print((a+b)*(a-b))
print((a+b)//(a-b))
print((a*b)+(a/b))
# Out:
# 52
# 12
# 640
# 1
# 624
# 4
# 641.6

# %%
first_name= vipul
last_name= trivedi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-9235017e1633> in <module>
#       1 first_name='vipul'
#       2 last_name='trivedi'
# ----> 3 print("My first name is {} and last name is {}".format(first_name,last_name))
#
# TypeError: 'str' object is not callable

# %%
print("My first name is {} and last name is {}".format(first_name,last_name))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-a23c68de8aff> in <module>
# ----> 1 print("My first name is {} and last name is {}".format(first_name,last_name))
#
# TypeError: 'str' object is not callable
